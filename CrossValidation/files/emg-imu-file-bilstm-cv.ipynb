# %%
import json
import numpy as np
from pandas.io.json import json_normalize

import os
import glob as gb
import tensorflow as tf

from sklearn.model_selection import train_test_split
import keras 
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM , Flatten , CuDNNLSTM , GRU, Bidirectional
from keras.layers import Dropout
import keras

from keras import callbacks
from keras.callbacks import  CSVLogger


# Model Evaluations
from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import KFold

# %%
def load_file(filepath,i):
    with open(filepath) as f:
        data = json.load(f)
    imu = data['imu']['data']
    emg = data['emg']['data']
    emg = np.array(emg)
    imu = np.array(imu)
    imu_gyr = np.array([(e['gyroscope']) for e in imu])
    imu_acc = np.array([(e['acceleration']) for e in imu])
    imu_orn = np.array([(e['orientation']) for e in imu])
    #timestamp = [i]
    #timestamp = np.repeat(timestamp, 400, axis=None)
    #timestamp= timestamp.reshape(400,1)
    dataset = tf.concat([emg, imu_gyr, imu_acc, imu_orn], axis=1, name='concat')
    dataset = np.array(dataset)
    return dataset

# %%
data_path = '../input/emgimu/An-EMG-and-IMU-Dataset-for-the-Italian-Sign-Language-Alphabet-master/Dataset/'

# %%
# For Files Data
X = []
y = []
i=0
for folder in  os.listdir(data_path) : 
    j=0
    files = gb.glob(pathname= str( data_path  + folder + '/*.json'))
    for file in files: 
        data = load_file(file,j)
        X.append(data)
        y.append(i)
        j+=1
    i+=1

print(f'we have {len(X)} items in X ')
# Out:
# 2022-10-26 20:03:14.353361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:14.354672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:14.825220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:14.826142: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:14.826959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:14.827761: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:14.832003: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 20:03:15.098751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:15.099656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:15.100439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:15.101314: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:15.102073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:15.102821: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.266312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.267305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.268087: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.268893: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.269666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.270382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-10-26 20:03:20.276398: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:03:20.277158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# we have 780 items in X

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.utils import shuffle
X, y = shuffle(X, y, random_state=20)

# %%
print('X shape is : ' , X.shape)
print('y shape is : ' , y.shape)
# Out:
# X shape is :  (780, 400, 18)
# y shape is :  (780,)

# %%
mapping = {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 
           'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 
           'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25}

# %%
def getcode(n) : 
    for x , y in mapping.items() : 
        if n == y : 
            return x

# %%
X = X.reshape(len(X), X.shape[1],18)
y = to_categorical(y)

# %%
print(X.shape)
# Out:
# (780, 400, 18)

# %% [markdown]
# # Building Model with files

# %%
kfold = KFold(n_splits=5, shuffle=True)

# %%
acc_per_fold = []
loss_per_fold = []
fold_no = 1
for train, test in kfold.split(X, y):

  # Model architecture
    model = Sequential()
    model.add(Bidirectional(CuDNNLSTM(units=265, return_sequences=True), input_shape =(400,18)))
    model.add(Bidirectional(CuDNNLSTM(units=128, return_sequences=True), input_shape =(400,18)))
    model.add(Dropout(rate=0.3))
    model.add(Flatten())
    model.add(Dense(128,activation='tanh'))
    model.add(Dropout(rate=0.3))
    model.add(Dense(64,activation='tanh'))
    model.add(Dense(26,activation='softmax'))


    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#     es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
#     checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath="./checkpoint-{epoch:02d}.hdf5",
#                                                       verbose=1, save_best_only=True,
#                                                       monitor='val_acc',mode='max')
#     csv_logger = CSVLogger('training_set_iranalysis3.csv',separator=',', append=False)




    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    
    history = model.fit(X[train], y[train], 
                        batch_size=128, epochs=40)

    
    scores = model.evaluate(X[test], y[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; \
    {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# 2022-10-26 20:08:41.505453: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/40
# 2022-10-26 20:08:46.191953: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 5/5 [==============================] - 11s 395ms/step - loss: 2.9681 - accuracy: 0.2163
# Epoch 2/40
# 5/5 [==============================] - 1s 211ms/step - loss: 1.8074 - accuracy: 0.5272
# Epoch 3/40
# 5/5 [==============================] - 1s 210ms/step - loss: 1.3551 - accuracy: 0.6747
# Epoch 4/40
# 5/5 [==============================] - 1s 211ms/step - loss: 1.0350 - accuracy: 0.8077
# Epoch 5/40
# 5/5 [==============================] - 1s 210ms/step - loss: 0.8338 - accuracy: 0.8638
# Epoch 6/40
# 5/5 [==============================] - 1s 211ms/step - loss: 0.6602 - accuracy: 0.8990
# Epoch 7/40
# 5/5 [==============================] - 1s 213ms/step - loss: 0.5605 - accuracy: 0.9263
# Epoch 8/40
# 5/5 [==============================] - 1s 212ms/step - loss: 0.4468 - accuracy: 0.9647
# Epoch 9/40
# 5/5 [==============================] - 1s 213ms/step - loss: 0.3618 - accuracy: 0.9744
# Epoch 10/40
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2986 - accuracy: 0.9840
# Epoch 11/40
# 5/5 [==============================] - 1s 210ms/step - loss: 0.2547 - accuracy: 0.9872
# Epoch 12/40
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2121 - accuracy: 0.9920
# Epoch 13/40
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1764 - accuracy: 0.9968
# Epoch 14/40
# 5/5 [==============================] - 1s 210ms/step - loss: 0.1451 - accuracy: 0.9968
# Epoch 15/40
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1228 - accuracy: 0.9984
# Epoch 16/40
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1073 - accuracy: 0.9968
# Epoch 17/40
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0957 - accuracy: 0.9984
# Epoch 18/40
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 19/40
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0733 - accuracy: 1.0000
# Epoch 20/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0640 - accuracy: 1.0000
# Epoch 21/40
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 22/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0573 - accuracy: 0.9984
# Epoch 23/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 24/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 25/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 26/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 27/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 28/40
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 29/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 30/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 31/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 32/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 33/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0214 - accuracy: 1.0000
# Score for fold 1: loss of 0.13971397280693054;     accuracy of 94.87179517745972%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/40
# 5/5 [==============================] - 3s 215ms/step - loss: 2.7523 - accuracy: 0.2292
# Epoch 2/40
# 5/5 [==============================] - 1s 217ms/step - loss: 1.6027 - accuracy: 0.5962
# Epoch 3/40
# 5/5 [==============================] - 1s 218ms/step - loss: 1.2179 - accuracy: 0.7324
# Epoch 4/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9631 - accuracy: 0.8173
# Epoch 5/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7699 - accuracy: 0.8926
# Epoch 6/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.6220 - accuracy: 0.9263
# Epoch 7/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.5102 - accuracy: 0.9263
# Epoch 8/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.4079 - accuracy: 0.9647
# Epoch 9/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.3278 - accuracy: 0.9792
# Epoch 10/40
# 5/5 [==============================] - 1s 224ms/step - loss: 0.2850 - accuracy: 0.9792
# Epoch 11/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.2312 - accuracy: 0.9872
# Epoch 12/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1921 - accuracy: 0.9968
# Epoch 13/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1612 - accuracy: 0.9984
# Epoch 14/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1335 - accuracy: 0.9984
# Epoch 15/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1092 - accuracy: 1.0000
# Epoch 16/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0981 - accuracy: 1.0000
# Epoch 17/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0833 - accuracy: 1.0000
# Epoch 18/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 19/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 20/40
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0636 - accuracy: 1.0000
# Epoch 21/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 22/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 23/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 24/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 25/40
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 26/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 27/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 28/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 29/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 30/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 31/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 32/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 33/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0202 - accuracy: 1.0000
# Score for fold 2: loss of 0.1115821823477745;     accuracy of 97.43589758872986%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/40
# 5/5 [==============================] - 3s 216ms/step - loss: 2.9808 - accuracy: 0.1522
# Epoch 2/40
# 5/5 [==============================] - 1s 218ms/step - loss: 1.7796 - accuracy: 0.5545
# Epoch 3/40
# 5/5 [==============================] - 1s 217ms/step - loss: 1.3369 - accuracy: 0.7276
# Epoch 4/40
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0074 - accuracy: 0.8413
# Epoch 5/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.7763 - accuracy: 0.9119
# Epoch 6/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.6174 - accuracy: 0.9343
# Epoch 7/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.4921 - accuracy: 0.9471
# Epoch 8/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.3868 - accuracy: 0.9744
# Epoch 9/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.3175 - accuracy: 0.9808
# Epoch 10/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.2537 - accuracy: 0.9872
# Epoch 11/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.2137 - accuracy: 0.9888
# Epoch 12/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1796 - accuracy: 0.9904
# Epoch 13/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1453 - accuracy: 0.9952
# Epoch 14/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.1279 - accuracy: 0.9952
# Epoch 15/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.1084 - accuracy: 0.9984
# Epoch 16/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0924 - accuracy: 0.9984
# Epoch 17/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0814 - accuracy: 0.9984
# Epoch 18/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0763 - accuracy: 1.0000
# Epoch 19/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0651 - accuracy: 0.9984
# Epoch 20/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0620 - accuracy: 0.9984
# Epoch 21/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0578 - accuracy: 0.9984
# Epoch 22/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 23/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 24/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 25/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 26/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 27/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 28/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 29/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 30/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 31/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 32/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 33/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0201 - accuracy: 1.0000
# Score for fold 3: loss of 0.2426806539297104;     accuracy of 92.30769276618958%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/40
# 5/5 [==============================] - 3s 218ms/step - loss: 2.5783 - accuracy: 0.2356
# Epoch 2/40
# 5/5 [==============================] - 1s 217ms/step - loss: 1.6169 - accuracy: 0.5929
# Epoch 3/40
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0988 - accuracy: 0.7788
# Epoch 4/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7887 - accuracy: 0.8862
# Epoch 5/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.5840 - accuracy: 0.9295
# Epoch 6/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.4629 - accuracy: 0.9599
# Epoch 7/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.3498 - accuracy: 0.9792
# Epoch 8/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.2715 - accuracy: 0.9920
# Epoch 9/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.2232 - accuracy: 0.9888
# Epoch 10/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.1793 - accuracy: 0.9984
# Epoch 11/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.1444 - accuracy: 1.0000
# Epoch 12/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.1193 - accuracy: 1.0000
# Epoch 13/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.1015 - accuracy: 0.9984
# Epoch 14/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0844 - accuracy: 1.0000
# Epoch 15/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0755 - accuracy: 1.0000
# Epoch 16/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0715 - accuracy: 1.0000
# Epoch 17/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 18/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 19/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 20/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 21/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 22/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 23/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 24/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 25/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 26/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 27/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 28/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 29/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 30/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 31/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 32/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 33/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 1s 278ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0169 - accuracy: 1.0000
# Score for fold 4: loss of 0.17759518325328827;     accuracy of 94.87179517745972%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/40
# 5/5 [==============================] - 3s 215ms/step - loss: 3.1356 - accuracy: 0.1667
# Epoch 2/40
# 5/5 [==============================] - 1s 215ms/step - loss: 1.9235 - accuracy: 0.4663
# Epoch 3/40
# 5/5 [==============================] - 1s 214ms/step - loss: 1.4583 - accuracy: 0.6587
# Epoch 4/40
# 5/5 [==============================] - 1s 215ms/step - loss: 1.2065 - accuracy: 0.7724
# Epoch 5/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9262 - accuracy: 0.8413
# Epoch 6/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.7381 - accuracy: 0.9135
# Epoch 7/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.6148 - accuracy: 0.9247
# Epoch 8/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.4881 - accuracy: 0.9503
# Epoch 9/40
# 5/5 [==============================] - 1s 219ms/step - loss: 0.3914 - accuracy: 0.9599
# Epoch 10/40
# 5/5 [==============================] - 1s 216ms/step - loss: 0.3218 - accuracy: 0.9760
# Epoch 11/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.2579 - accuracy: 0.9824
# Epoch 12/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.2110 - accuracy: 0.9888
# Epoch 13/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1792 - accuracy: 0.9904
# Epoch 14/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1513 - accuracy: 0.9920
# Epoch 15/40
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1343 - accuracy: 0.9952
# Epoch 16/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.1155 - accuracy: 0.9984
# Epoch 17/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.1031 - accuracy: 0.9968
# Epoch 18/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0912 - accuracy: 0.9984
# Epoch 19/40
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0827 - accuracy: 1.0000
# Epoch 20/40
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0704 - accuracy: 1.0000
# Epoch 21/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 22/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0611 - accuracy: 1.0000
# Epoch 23/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 24/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 25/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 26/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 27/40
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 28/40
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 29/40
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 30/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 31/40
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 32/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 33/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0219 - accuracy: 1.0000
# Score for fold 5: loss of 0.08865264058113098;     accuracy of 97.43589758872986%

# %%
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.13971397280693054 - Accuracy: 94.87179517745972%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.1115821823477745 - Accuracy: 97.43589758872986%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.2426806539297104 - Accuracy: 92.30769276618958%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.17759518325328827 - Accuracy: 94.87179517745972%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.08865264058113098 - Accuracy: 97.43589758872986%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.38461565971375 (+- 1.91879854551476)
# > Loss: 0.15204492658376695
# ------------------------------------------------------------------------
