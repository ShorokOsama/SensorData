# %%
import json
import numpy as np
from pandas.io.json import json_normalize

import os
import glob as gb
import tensorflow as tf

from sklearn.model_selection import train_test_split
import keras 
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM , Flatten , CuDNNLSTM , GRU, Bidirectional, Conv1D, MaxPooling1D
from keras.layers import Dropout
import keras

from keras import callbacks
from keras.callbacks import  CSVLogger


# Model Evaluations
from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import KFold

# %%
def load_file(filepath,i):
    with open(filepath) as f:
        data = json.load(f)
    imu = data['imu']['data']
    emg = data['emg']['data']
    emg = np.array(emg)
    imu = np.array(imu)
    imu_gyr = np.array([(e['gyroscope']) for e in imu])
    imu_acc = np.array([(e['acceleration']) for e in imu])
    imu_orn = np.array([(e['orientation']) for e in imu])
    #timestamp = [i]
    #timestamp = np.repeat(timestamp, 400, axis=None)
    #timestamp= timestamp.reshape(400,1)
    dataset = tf.concat([emg, imu_gyr, imu_acc, imu_orn], axis=1, name='concat')
    dataset = np.array(dataset)
    return dataset

# %%
data_path = '../input/emgimu/An-EMG-and-IMU-Dataset-for-the-Italian-Sign-Language-Alphabet-master/Dataset/'

# %%
# For Files Data
X = []
y = []
i=0
for folder in  os.listdir(data_path) : 
    j=0
    files = gb.glob(pathname= str( data_path  + folder + '/*.json'))
    for file in files: 
        data = load_file(file,j)
        X.append(data)
        y.append(i)
        j+=1
    i+=1

print(f'we have {len(X)} items in X ')
# Out:
# 2022-10-26 20:22:42.795360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:42.796270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:42.954693: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:42.955638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:42.956414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:42.957166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:42.959871: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 20:22:43.218852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:43.219739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:43.220527: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:43.221232: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:43.221921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:43.222759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.698166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.699180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.700034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.700854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.701706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.702466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-10-26 20:22:46.707224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-26 20:22:46.708012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# we have 780 items in X

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.utils import shuffle
X, y = shuffle(X, y, random_state=20)

# %%
print('X shape is : ' , X.shape)
print('y shape is : ' , y.shape)
# Out:
# X shape is :  (780, 400, 18)
# y shape is :  (780,)

# %%
mapping = {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 
           'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 
           'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25}

# %%
def getcode(n) : 
    for x , y in mapping.items() : 
        if n == y : 
            return x

# %%
X = X.reshape(len(X), X.shape[1],18)
y = to_categorical(y)

# %%
print(X.shape)
# Out:
# (780, 400, 18)

# %% [markdown]
# # Building Model with files

# %%
kfold = KFold(n_splits=5, shuffle=True)

# %%
acc_per_fold = []
loss_per_fold = []
fold_no = 1
for train, test in kfold.split(X, y):

  # Model architecture
    model = Sequential()
    model.add(Conv1D(256, 3, activation='relu', input_shape =(400,18)))
    model.add(MaxPooling1D(3))
    model.add(Conv1D(128, 3, activation='relu'))
    model.add(MaxPooling1D(3))
    model.add(Conv1D(64, 3, activation='relu'))
    model.add(MaxPooling1D(3))
    model.add(Flatten())
    model.add(Dense(128,activation='tanh'))
    model.add(Dense(26,activation='softmax'))


    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#     es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
#     checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath="./checkpoint-{epoch:02d}.hdf5",
#                                                       verbose=1, save_best_only=True,
#                                                       monitor='val_acc',mode='max')
#     csv_logger = CSVLogger('training_set_iranalysis3.csv',separator=',', append=False)




    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    
    history = model.fit(X[train], y[train], 
                        batch_size=128, epochs=40)

    
    scores = model.evaluate(X[test], y[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; \
    {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# 2022-10-26 20:25:19.634695: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/40
# 2022-10-26 20:25:21.846381: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 5/5 [==============================] - 10s 61ms/step - loss: 3.4698 - accuracy: 0.0673
# Epoch 2/40
# 5/5 [==============================] - 0s 18ms/step - loss: 2.9993 - accuracy: 0.1859
# Epoch 3/40
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7749 - accuracy: 0.2163
# Epoch 4/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.5273 - accuracy: 0.3446
# Epoch 5/40
# 5/5 [==============================] - 0s 23ms/step - loss: 2.3171 - accuracy: 0.4151
# Epoch 6/40
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1314 - accuracy: 0.4663
# Epoch 7/40
# 5/5 [==============================] - 0s 22ms/step - loss: 1.9740 - accuracy: 0.5385
# Epoch 8/40
# 5/5 [==============================] - 0s 18ms/step - loss: 1.8126 - accuracy: 0.5946
# Epoch 9/40
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6738 - accuracy: 0.6651
# Epoch 10/40
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5408 - accuracy: 0.7436
# Epoch 11/40
# 5/5 [==============================] - 0s 17ms/step - loss: 1.4037 - accuracy: 0.7869
# Epoch 12/40
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2705 - accuracy: 0.8413
# Epoch 13/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1736 - accuracy: 0.8526
# Epoch 14/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0923 - accuracy: 0.8734
# Epoch 15/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.9780 - accuracy: 0.9022
# Epoch 16/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.8921 - accuracy: 0.9343
# Epoch 17/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7801 - accuracy: 0.9423
# Epoch 18/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7033 - accuracy: 0.9551
# Epoch 19/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6061 - accuracy: 0.9615
# Epoch 20/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5429 - accuracy: 0.9744
# Epoch 21/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4715 - accuracy: 0.9712
# Epoch 22/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4162 - accuracy: 0.9792
# Epoch 23/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3622 - accuracy: 0.9856
# Epoch 24/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3295 - accuracy: 0.9840
# Epoch 25/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2918 - accuracy: 0.9872
# Epoch 26/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2633 - accuracy: 0.9872
# Epoch 27/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2393 - accuracy: 0.9888
# Epoch 28/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2092 - accuracy: 0.9904
# Epoch 29/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1896 - accuracy: 0.9936
# Epoch 30/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1698 - accuracy: 0.9936
# Epoch 31/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1570 - accuracy: 0.9936
# Epoch 32/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1427 - accuracy: 0.9936
# Epoch 33/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1312 - accuracy: 0.9968
# Epoch 34/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1206 - accuracy: 0.9968
# Epoch 35/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1115 - accuracy: 0.9968
# Epoch 36/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1034 - accuracy: 0.9968
# Epoch 37/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0968 - accuracy: 0.9968
# Epoch 38/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0913 - accuracy: 0.9968
# Epoch 39/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0848 - accuracy: 0.9968
# Epoch 40/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0801 - accuracy: 0.9968
# Score for fold 1: loss of 0.5523018836975098;     accuracy of 86.53846383094788%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/40
# 5/5 [==============================] - 1s 17ms/step - loss: 3.5194 - accuracy: 0.0689
# Epoch 2/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.9961 - accuracy: 0.1506
# Epoch 3/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7651 - accuracy: 0.2484
# Epoch 4/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6010 - accuracy: 0.2949
# Epoch 5/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3998 - accuracy: 0.3686
# Epoch 6/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2813 - accuracy: 0.4391
# Epoch 7/40
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1041 - accuracy: 0.5256
# Epoch 8/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9917 - accuracy: 0.5417
# Epoch 9/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8311 - accuracy: 0.6058
# Epoch 10/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6885 - accuracy: 0.6314
# Epoch 11/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5628 - accuracy: 0.6843
# Epoch 12/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4234 - accuracy: 0.7484
# Epoch 13/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3132 - accuracy: 0.7837
# Epoch 14/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1865 - accuracy: 0.8381
# Epoch 15/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1106 - accuracy: 0.8718
# Epoch 16/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9943 - accuracy: 0.8702
# Epoch 17/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8853 - accuracy: 0.9087
# Epoch 18/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8051 - accuracy: 0.9006
# Epoch 19/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7011 - accuracy: 0.9423
# Epoch 20/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6275 - accuracy: 0.9583
# Epoch 21/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5458 - accuracy: 0.9647
# Epoch 22/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4813 - accuracy: 0.9696
# Epoch 23/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4224 - accuracy: 0.9792
# Epoch 24/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3694 - accuracy: 0.9856
# Epoch 25/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3214 - accuracy: 0.9840
# Epoch 26/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2866 - accuracy: 0.9872
# Epoch 27/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2462 - accuracy: 0.9888
# Epoch 28/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2154 - accuracy: 0.9888
# Epoch 29/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1847 - accuracy: 0.9904
# Epoch 30/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1684 - accuracy: 0.9904
# Epoch 31/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1526 - accuracy: 0.9904
# Epoch 32/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1404 - accuracy: 0.9904
# Epoch 33/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1264 - accuracy: 0.9920
# Epoch 34/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1161 - accuracy: 0.9936
# Epoch 35/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1065 - accuracy: 0.9936
# Epoch 36/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0975 - accuracy: 0.9952
# Epoch 37/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0907 - accuracy: 0.9952
# Epoch 38/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0844 - accuracy: 0.9968
# Epoch 39/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0785 - accuracy: 0.9984
# Epoch 40/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0730 - accuracy: 0.9984
# Score for fold 2: loss of 0.681763231754303;     accuracy of 82.05128312110901%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/40
# 5/5 [==============================] - 1s 21ms/step - loss: 3.4188 - accuracy: 0.0897
# Epoch 2/40
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7072 - accuracy: 0.2308
# Epoch 3/40
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2708 - accuracy: 0.3910
# Epoch 4/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9915 - accuracy: 0.4679
# Epoch 5/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.7342 - accuracy: 0.5497
# Epoch 6/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5420 - accuracy: 0.6282
# Epoch 7/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3248 - accuracy: 0.7308
# Epoch 8/40
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1566 - accuracy: 0.7821
# Epoch 9/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9906 - accuracy: 0.8317
# Epoch 10/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8478 - accuracy: 0.8590
# Epoch 11/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7239 - accuracy: 0.8942
# Epoch 12/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6135 - accuracy: 0.9199
# Epoch 13/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5336 - accuracy: 0.9471
# Epoch 14/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4521 - accuracy: 0.9663
# Epoch 15/40
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3803 - accuracy: 0.9712
# Epoch 16/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3231 - accuracy: 0.9840
# Epoch 17/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2764 - accuracy: 0.9872
# Epoch 18/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2316 - accuracy: 0.9936
# Epoch 19/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1997 - accuracy: 0.9968
# Epoch 20/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1737 - accuracy: 0.9968
# Epoch 21/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1510 - accuracy: 0.9984
# Epoch 22/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1337 - accuracy: 0.9968
# Epoch 23/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1194 - accuracy: 1.0000
# Epoch 24/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1079 - accuracy: 1.0000
# Epoch 25/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0983 - accuracy: 1.0000
# Epoch 26/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0896 - accuracy: 1.0000
# Epoch 27/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 28/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0748 - accuracy: 1.0000
# Epoch 29/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0693 - accuracy: 1.0000
# Epoch 30/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 31/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0600 - accuracy: 1.0000
# Epoch 32/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 33/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0520 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0359 - accuracy: 1.0000
# Score for fold 3: loss of 0.5059210658073425;     accuracy of 87.82051205635071%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/40
# 5/5 [==============================] - 1s 18ms/step - loss: 3.3368 - accuracy: 0.1058
# Epoch 2/40
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8398 - accuracy: 0.1843
# Epoch 3/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.5824 - accuracy: 0.3013
# Epoch 4/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3595 - accuracy: 0.3798
# Epoch 5/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1487 - accuracy: 0.4487
# Epoch 6/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9833 - accuracy: 0.4936
# Epoch 7/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8079 - accuracy: 0.5529
# Epoch 8/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6378 - accuracy: 0.6699
# Epoch 9/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4809 - accuracy: 0.7324
# Epoch 10/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3616 - accuracy: 0.7708
# Epoch 11/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2204 - accuracy: 0.7885
# Epoch 12/40
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0695 - accuracy: 0.8590
# Epoch 13/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9571 - accuracy: 0.8942
# Epoch 14/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8631 - accuracy: 0.8974
# Epoch 15/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7499 - accuracy: 0.9327
# Epoch 16/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6716 - accuracy: 0.9375
# Epoch 17/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5973 - accuracy: 0.9503
# Epoch 18/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5318 - accuracy: 0.9647
# Epoch 19/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4700 - accuracy: 0.9728
# Epoch 20/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4216 - accuracy: 0.9776
# Epoch 21/40
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3754 - accuracy: 0.9824
# Epoch 22/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3332 - accuracy: 0.9888
# Epoch 23/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2950 - accuracy: 0.9872
# Epoch 24/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2611 - accuracy: 0.9920
# Epoch 25/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2320 - accuracy: 0.9904
# Epoch 26/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2102 - accuracy: 0.9920
# Epoch 27/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1830 - accuracy: 0.9920
# Epoch 28/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1665 - accuracy: 0.9952
# Epoch 29/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1490 - accuracy: 0.9952
# Epoch 30/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1358 - accuracy: 0.9968
# Epoch 31/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1235 - accuracy: 0.9968
# Epoch 32/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1139 - accuracy: 0.9968
# Epoch 33/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1058 - accuracy: 1.0000
# Epoch 34/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0980 - accuracy: 1.0000
# Epoch 35/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0909 - accuracy: 1.0000
# Epoch 36/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0852 - accuracy: 1.0000
# Epoch 37/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0795 - accuracy: 1.0000
# Epoch 38/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 39/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 40/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0643 - accuracy: 1.0000
# Score for fold 4: loss of 0.6424242854118347;     accuracy of 80.7692289352417%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/40
# 5/5 [==============================] - 1s 21ms/step - loss: 3.5685 - accuracy: 0.0641
# Epoch 2/40
# 5/5 [==============================] - 0s 20ms/step - loss: 3.1286 - accuracy: 0.1298
# Epoch 3/40
# 5/5 [==============================] - 0s 22ms/step - loss: 2.8981 - accuracy: 0.1923
# Epoch 4/40
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7317 - accuracy: 0.2564
# Epoch 5/40
# 5/5 [==============================] - 0s 17ms/step - loss: 2.5344 - accuracy: 0.3301
# Epoch 6/40
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3782 - accuracy: 0.3686
# Epoch 7/40
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1938 - accuracy: 0.4407
# Epoch 8/40
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0448 - accuracy: 0.5465
# Epoch 9/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8965 - accuracy: 0.5465
# Epoch 10/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.7659 - accuracy: 0.5913
# Epoch 11/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6212 - accuracy: 0.6490
# Epoch 12/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5178 - accuracy: 0.7051
# Epoch 13/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3935 - accuracy: 0.7388
# Epoch 14/40
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2943 - accuracy: 0.7724
# Epoch 15/40
# 5/5 [==============================] - 0s 23ms/step - loss: 1.1679 - accuracy: 0.8221
# Epoch 16/40
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0796 - accuracy: 0.8349
# Epoch 17/40
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9788 - accuracy: 0.8942
# Epoch 18/40
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8842 - accuracy: 0.8830
# Epoch 19/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7968 - accuracy: 0.9327
# Epoch 20/40
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7204 - accuracy: 0.9423
# Epoch 21/40
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6329 - accuracy: 0.9567
# Epoch 22/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5666 - accuracy: 0.9647
# Epoch 23/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5048 - accuracy: 0.9712
# Epoch 24/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4595 - accuracy: 0.9776
# Epoch 25/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4056 - accuracy: 0.9808
# Epoch 26/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3550 - accuracy: 0.9888
# Epoch 27/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3187 - accuracy: 0.9904
# Epoch 28/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2904 - accuracy: 0.9952
# Epoch 29/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2604 - accuracy: 0.9984
# Epoch 30/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2366 - accuracy: 0.9984
# Epoch 31/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2160 - accuracy: 0.9984
# Epoch 32/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1988 - accuracy: 0.9984
# Epoch 33/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1826 - accuracy: 0.9984
# Epoch 34/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1671 - accuracy: 0.9984
# Epoch 35/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1532 - accuracy: 0.9984
# Epoch 36/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1433 - accuracy: 0.9984
# Epoch 37/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1336 - accuracy: 0.9984
# Epoch 38/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1236 - accuracy: 0.9984
# Epoch 39/40
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1150 - accuracy: 0.9984
# Epoch 40/40
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1072 - accuracy: 0.9984
# Score for fold 5: loss of 0.6797571778297424;     accuracy of 85.25640964508057%

# %%
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.5523018836975098 - Accuracy: 86.53846383094788%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.681763231754303 - Accuracy: 82.05128312110901%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.5059210658073425 - Accuracy: 87.82051205635071%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6424242854118347 - Accuracy: 80.7692289352417%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6797571778297424 - Accuracy: 85.25640964508057%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 84.48717951774597 (+- 2.6708551411262014)
# > Loss: 0.6124335289001465
# ------------------------------------------------------------------------
